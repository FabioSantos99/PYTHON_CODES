# %% [markdown]
# https://forms.gle/K1advr7pWkZXYFaa6

# %%
from selenium import webdriver
from time import sleep

navegador = webdriver.Chrome()
navegador.get("https://forms.office.com/r/k0nYFN2LxM")

navegador.find_element("xpath",'//*[@id="form-main-content1"]/div/div/div[2]/div[2]/div/button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20804\2586589952.py in <module>
#       5 navegador.get("https://forms.office.com/r/k0nYFN2LxM")
#       6
# ----> 7 navegador.find_element("xpath",'//*[@id="form-main-content1"]/div/div/div[2]/div[2]/div/button').click()
#       8
#       9
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
import pandas as pd

tabela = pd.read_excel("Emitir.xlsx")
display(tabela)
# Out:
#             CPF                       Email          Descrição  Valor
# 0   11122233344   emailaleatorio1@gmail.com     Curso de Excel   1500
# 1   11122233355   emailaleatorio2@gmail.com     Curso de Excel   1500
# 2   11122233366   emailaleatorio3@gmail.com     Curso de Excel   1500
# 3   11122233377   emailaleatorio4@gmail.com       Curso de VBA   2500
# 4   11122233388   emailaleatorio5@gmail.com    Curso de Python   3000
# 5   11122233399   emailaleatorio6@gmail.com  Curso de Power BI   2900
# 6   11122233410   emailaleatorio7@gmail.com  Curso de Power BI   2900
# 7   11122233421   emailaleatorio8@gmail.com    Curso de Python   3000
# 8   11122233432   emailaleatorio9@gmail.com  Curso de Power BI   2900
# 9   11122233443  emailaleatorio10@gmail.com    Curso de Python   3000
# 10  11122233454  emailaleatorio11@gmail.com    Curso de Python   3000
# 11  11122233465  emailaleatorio12@gmail.com    Curso de Python   3000
# ...

# %%
for i, cpf in enumerate(tabela["CPF"]):
    email = tabela.loc[i, "Email"]
    descricao = tabela.loc[i, "Descricão"]
    valor = tabela.loc[i, "Valor"]
