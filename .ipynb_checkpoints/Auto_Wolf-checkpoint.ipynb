# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from time import sleep

options = Options()
options.add_argument('profile-directory=Default')
options.add_argument('user-data-dir=/tmp/browser')
options.add_argument("start-maximized")

webdriver_service = Service('C:\webdrivers\chromedriver.exe')
driver = webdriver.Chrome(options=options, service=webdriver_service)
wait = WebDriverWait(driver, 10)

url = "https://wolf.bet/login"

driver.get(url)

# %%
wait.until(EC.element_to_be_clickable((By.CLASS_NAME,'x'))).click()
sleep(3)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("Hi Everyone, good afternoon")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(493)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("good luck")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(1035)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("gooood earn for everyone")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(504)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("Let's to get more cryptos today and ever")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(944)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("work in usd")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(800)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("go to the nice rolls")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(598)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('have a nice fun')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('run to the win')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("It's time to bankrupt the wolf now")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('next to the win now')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(799)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('keep on earning')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(950)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('have a fun an nice rolls')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(932)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("It's time to earn usdt")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("I almost earn 50 usd coins")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(903)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('have a nice rolls all')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('Now to the benefits')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("let's go to the wolf's hunt")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(1058)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('have fun')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(580)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('keep on earning and saving')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(629)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('profits and luck on your rolls')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(1234)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('go to the hunt')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(722)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('have fun my friends')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(567)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('go to the top')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(945)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('Luck, where you are here!')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(1374)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys('hello again')
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(550)

wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("go to the next")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()
sleep(711)


wait.until(EC.element_to_be_clickable((By.ID,'chat-input'))).send_keys("I'm be back")
sleep(2)
wait.until(EC.element_to_be_clickable((By.NAME,'chat_message_submit'))).click()

sleep(7)

wait.until(EC.element_to_be_clickable((By.CLASS_NAME,'x'))).click()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from time import sleep

options = Options()
options.add_argument('profile-directory=Default')
options.add_argument('user-data-dir=/tmp/browser')
options.add_argument("start-maximized")
options.add_argument("--mute-audio--")

webdriver_service = Service('C:\webdrivers\chromedriver.exe')
driver = webdriver.Chrome(options=options, service=webdriver_service)



urls = ("https://windice.io", "https://wolf.bet")


for url in urls.index():
     driver.get(url)
        
        
dormir = (6, 5)

for dormires in dormir.index():
        sleep(dormires)
